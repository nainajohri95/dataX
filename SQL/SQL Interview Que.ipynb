# %%
Find product that is never ordered
products:
products_id     	      name
1                          Laptop
2                          Smartphone
3                          Headphones
4                          Monitor
order_items

id            order_id 	   product_id
1            101                     1
2            102                     2
3            103                     1

select p.products_id, p.name from products p
left join order_items o 
on p.products_id = o.prodcut_id
where o.product_id is null;

# %%
Table A
Id: 1,1,1,1,3,3,4

Table B
id: 1,1,1,3,3,4,5 

left join:- no. of 1 in table A =3, no. of 3 in table A=2, no. of 4 in table A is 1

inner join:- 3*2+2*2+1*1= 6+4+1= 11
left join :- 11 +1 =12
right join :- 11+1 =12
full-outer join:- 1+1 = 2
