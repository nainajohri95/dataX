# %%
#Find all the employees who hold the Managerial Position
select * from employee where (employee_id in (select manager_id from employee));

# %%
# %sql
select current_date()

# %%
#fetch alternative records 
select * from employee where id%2 = 0  # for even records
select * from employee where id%2 =1 # for odd records
